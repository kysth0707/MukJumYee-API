# %% [markdown]
# https://digitalnk.com/blog/2017/09/15/ocr-for-north-korean-archival-data-part-1-2/#

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import pytesseract
from PIL import Image
import numpy as np
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
pytesseract.__version__
# Out:
# '0.3.10'

# %%
img = cv.cvtColor(cv.imread(r'E:\GithubProjects\HIDDEN\ImageFromVideo\tests\clearImage.png'), cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
tessdata_dir_config = '--tessdata-dir "C:\\Program Files\\Tesseract-OCR\\tessdata"'
 
print(pytesseract.image_to_string(img, lang='kor', config=tessdata_dir_config))
# Out:
# 모든 수학 분야는 자기
#
# 가가우스의 상관 불평등
# 괜실베이니아 주림 대호
# 말했다 "그 문제를 해결:
# 30년이나 매달렸다” 수및
# 계산을 히고 정교한 기해:
# 전을 이끌어 내기도 했지(
# 러는 혹시 가우스의 싱곱

# %%
import cv2
 
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret2,th2 = cv2.threshold(gray,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# %%
contours, hierarchy = cv2.findContours(th2,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
img2 = img.copy()
for contour in contours:
    x, y, width, height = cv2.boundingRect(contour)

# %%
list_area = []
list_rect = []
new_image = np.zeros(np.shape(th2))
new_image.fill(255)
 
for contour in contours:
    x, y, width, height = cv2.boundingRect(contour)
    area = width * height
    if area > 50 and area < max_cont_area:
        list_rect.append((x, y, width, height))
        list_area.append(width * height)
        new_image[y : y + height, x: x + width] = th2[y : y + height, x: x + width]
# Out:
#   Cell In [22], line 9
#     if area &amp;gt; 50 and area &amp;lt; max_cont_area:
#                 ^
# SyntaxError: invalid syntax
