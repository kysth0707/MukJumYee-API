# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
cv.__version__
# Out:
# '4.6.0'

# %%
VIDEO_RESOLUTION = (9*20, 19*20)

# %%
cap = cv.VideoCapture('test.mp4')

_, frame1 = cap.read()
# for i in range(10):
#     cap.read()
_, frame2 = cap.read()

frame1 = cv.flip(cv.flip(frame1, 0), 1)
frame1 = cv.resize(frame1, VIDEO_RESOLUTION)
frame2 = cv.flip(cv.flip(frame2, 0), 1)
frame2 = cv.resize(frame2, VIDEO_RESOLUTION)

# %%
plt.imshow(frame1)

# %%
plt.imshow(frame2)

# %%
stitcher = cv.Stitcher_create()

# %%
_, dst = stitcher.stitch([frame1, frame2])

# %%
plt.imshow(dst)
